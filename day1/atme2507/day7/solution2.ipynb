# %%
import pandas as pd
df=pd.read_csv('BigBasket Products.csv')
print(df.head())
print(df.shape)
print(df.iloc[10:20,:])
print(df.dtypes)
# Out:
#    index                                            product  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg
# 1      2                              Water Bottle - Orange
# 2      3                     Brass Angle Deep - Plain, No.2
# 3      4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      5                 Creme Soft Soap - For Hands & Body
#
#                  category           sub_category              brand  \
# 0        Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 1  Kitchen, Garden & Pets  Storage & Accessories         Mastercook
# 2    Cleaning & Household            Pooja Needs                Trm
# 3    Cleaning & Household   Bins & Bathroom Ware             Nakoda
# 4        Beauty & Hygiene       Bath & Hand Wash              Nivea
#
#    sale_price  market_price                      type  rating  \
# 0       220.0         220.0          Hair Oil & Serum     4.1
# 1       180.0         180.0    Water & Fridge Bottles     2.3
# ...

# %%
print(df.iloc[10:20,:])
# Out:
#     index                                     product              category  \
# 10     11                    Wheat Grass Powder - Raw  Gourmet & World Food
# 11     12              Butter Cookies Gold Collection  Gourmet & World Food
# 12     13             Face Wash - Oil Control, Active      Beauty & Hygiene
# 13     14           Mold & Mildew Remover with Bleach  Cleaning & Household
# 14     15  Just Spray - Mosquito Repellent Room Spray  Cleaning & Household
# 15     16    Dove Plastic Soap Case - Assorted Colour  Cleaning & Household
# 16     17              Smooth Skin Oil - For Dry Skin      Beauty & Hygiene
# 17     18                              Salted Pumpkin  Gourmet & World Food
# 18     19                        Flax Seeds - Roasted  Gourmet & World Food
# 19     20                   Organic Tofu - Soy Paneer  Gourmet & World Food
#
#                 sub_category            brand  sale_price  market_price  \
# ...

# %%
Bathing_Bars=df[(df['sub_category']=='Bath & Hand Wash')&
            (df['rating']>4)&
            (df['type']=='Bathing Bars & Soaps')]
print(Bathing_Bars)
# Out:
#        index                                          product  \
# 4          5               Creme Soft Soap - For Hands & Body
# 41        42                        Lemon & Tea Tree Oil Soap
# 77        78                    & Moms Bathing Soap - Jasmine
# 88        89                 Bathing Soap - Sandal & Turmeric
# 163      164           Nomarks - Antimarks Soap For Oily Skin
# ...      ...                                              ...
# 26874  26875                                Cooling Mint Soap
# 27111  27112                        Exotic Rose Handmade Soap
# 27172  27173     Cold Processed Papaya Cucumber Handmade Soap
# 27277  27278              Bathing Soap - Jasmine & Milk Cream
# 27458  27459  Fresh Splash Water Lily & Cooling Mint Soap Bar
#
#                category      sub_category        brand  sale_price  \
# 4      Beauty & Hygiene  Bath & Hand Wash        Nivea      162.00
# 41     Beauty & Hygiene  Bath & Hand Wash        Liril      360.00
# ...

# %%
Cleaning=df[(df['sub_category']=='Bins & Bathroom Ware')&
            (df['rating']>4.1)&
            (df['type']=='Laundry, Storage Baskets')]
print(Cleaning)
# Out:
#        index                                            product  \
# 527      528  Cereal Flip Lid Container/Storage Jar - Assort...
# 2265    2266  Multi Utility Transparent Plastic Basket/Tray ...
# 4946    4947  Star Premium Multipurpose Plastic Basket - Sma...
# 5415    5416  Fruit & Vegetable Colander/Basket/Strainer - S...
# 5849    5850  Della Storage Container With Lid - Assorted Co...
# 6280    6281  Plastic Basket Fruit & Vegetable Colande/Strai...
# 6291    6292               Washing Net Bag - For Socks/Stocking
# 6878    6879  Plastic Basket Fruit & Vegetable Colander/Stra...
# 7851    7852          Pluto Storage Container - Assorted Colour
# 9807    9808          Pluto Storage Container - Assorted Colour
# 11875  11876  Fruit & Vegetable Plastic Basket/Colander/Stra...
# 11925  11926  Della Storage Container With Lid - Assorted Co...
# 12550  12551          Washing Net Bag - For Bag Shirts/T-Shirts
# 13798  13799  Clothes Storage Laundry Bag - Cacti Printed, B...
# ...

# %%
hair_oil=df[(df['sub_category']=='Hair Care')&
            (df['rating']>4)&
            (df['type']=='Hair Oil & Serum')]
print(hair_oil)
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 172      173                                  Pain Relief - Oil
# 359      360                               Hair Spa Oil Therapy
# 766      767  Evening Primrose Oil - Vegetarian Capsule (500...
# 1340    1341                        Natural Nourishing Hair Oil
# ...      ...                                                ...
# 26261  26262                       Shanti - Badam Amla Hair Oil
# 26274  26275                                  Herbal Hair Serum
# 26433  26434  Organic Extra Virgin Olive Oil - Pure Coldpres...
# 26682  26683                              Hair Oil - Kesh Kanti
# 27445  27446  Organic Virgin Coconut Oil - Pure Coldpressed ...
#
#                category sub_category              brand  sale_price  \
# 0      Beauty & Hygiene    Hair Care  Sri Sri Ayurveda        220.0
# ...

# %%
kitchen=df[(df['category']=='Kitchen, Garden & Pets')&
            (df['rating']>3.2)&
            (df['type']=='Water & Fridge Bottles')]
print(kitchen)
# Out:
#        index                                            product  \
# 139      140        Glass Water Bottle - Aquaria Organic Purple
# 1038    1039  Glass Water Bottle With Round Base - Transpare...
# 1701    1702                H2O Unbreakable Water Bottle - Pink
# 2209    2210                            Water Bottle H2O Purple
# 2704    2705               H2O Unbreakable Water Bottle - Green
# ...      ...                                                ...
# 27003  27004          Pet Plastic Water Bottle - Blue, Victoria
# 27005  27006                 Sante Infuser Water Bottle - Black
# 27208  27209  Plastic Bottle - Lemon Green, Flip Top, All Fr...
# 27221  27222  Glass Bottle With Removable Fabric Cover - Bro...
# 27512  27513            Water Bottle - Fridge, Tulip, Dark Blue
#
#                      category           sub_category       brand  sale_price  \
# 139    Kitchen, Garden & Pets  Storage & Accessories       Cello       369.0
# ...

# %%
hair_oil.to_csv('hair_oil.csv')

# %%
Bathing_Bars.to_csv('Bathing_Bars.csv')

# %%
kitchen.to_csv('kitchen.csv')

# %%
Cleaning.to_csv('cleaning.csv')
