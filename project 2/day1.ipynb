# %%
#for minimum
def lesser_of_two_events(a,b):
    if a%2==0 and b%2==0:
       return min(a,b)
#check
lesser_of_two_events(2,4)
# Out:
# 2

# %%
#for maximum
def lesser_of_two_events(a,b):
    if a%2==0 and b%2==0:
       return min(a,b)
    else:
       return max(a,b)
   #check
print(lesser_of_two_events(2,4))
print(lesser_of_two_events(2,5))
# Out:
# 2
# 5

# %%
5//2   #it give quotient
# Out:
# 2

# %%
5%3  #it give remainder
# Out:
# 2

# %%
type(5/2)
# Out:
# float

# %%
type(15//2)
# Out:
# int

# %%
type(14%2)
# Out:
# int

# %%
type(3+5.0)
# Out:
# float

# %%
2 ==2
# Out:
# True

# %%
10/3==10*(1/3)
# Out:
# False

# %%
10/3==(1/3)*10
# Out:
# False

# %%
#write a function that takes in a list of integers and returns true if it contains 007 in order
def spy_game(nums):
    code = [0,0,7]
    for n in nums:
        if n == code[0]:
            code.pop(0)
            if not code:
                return True
    return False
#check
print(spy_game([1,2,4,0,0,7,5]))  
print(spy_game([1,0,2,4,0,5,7]))
print(spy_game([1,7,2,0,4,5,0]))
# Out:
# True
# True
# False
